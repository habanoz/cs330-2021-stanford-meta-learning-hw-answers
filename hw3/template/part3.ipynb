# %%
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
maml = np.array([[1, 0.899, 0.007], [2, 0.932, 0.005], [4, 0.942, 0.005], [6, 0.952, 0.004], [8, 0.953, 0.004], [10, 0.954, 0.004]])

# %%
plt.errorbar(maml[:,0], maml[:,1], yerr=maml[:,2], label='MAML')
plt.grid()

# %%
protonet = np.array([[1, 0.984, 0.002], [2, 0.991, 0.002], [4, 0.996, 0.001], [6, 0.996, 0.001], [8, 0.996, 0.001], [10, 0.997, 0.001]])

# %%
plt.errorbar(protonet[:,0], protonet[:,1], yerr=protonet[:,2], label='Protonet')
plt.grid()

# %%
plt.errorbar(protonet[:,0], protonet[:,1], yerr=protonet[:,2], label='Protonet')
plt.errorbar(maml[:,0], maml[:,1], yerr=maml[:,2], label='MAML')
plt.grid()
plt.legend()
